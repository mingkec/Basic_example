# %%
#environment is Python 3.6, tensorflow 1.3

# %%
from Taffetas.Taffetas import service_operator
from Taffetas.ImageDataGenerator.ImageDataGenerator_single import batch_data_generator
from example_config import system_setting
import tensorflow as tf
from matplotlib import pyplot as plt
import os
import multiprocessing 
import subprocess

# %%
system_setting['logdir']
# Out:
# '/home/Mingke.Chen/restructure/log'

# %%
#start TensorBoard 
# the default TensorBoard is http://localhost:6006/
def start_TensorBoard(log_path):
    log_path='--logdir='+log_path
    subprocess.call(['tensorboard',log_path])
p = multiprocessing.Process(target=start_TensorBoard, args=(system_setting['logdir'],))
p.start()

# %%
#set the name of this job
system_setting['model_name']= 'example'

# %% [markdown]
# [**The data can be downloaded at here**](https://www.kaggle.com/c/state-farm-distracted-driver-detection)<br>

# %%
# define data augmentation algorithms
setting={
    #'rotation_range': 100,
    'width_shift_range':0.05,
    'height_shift_range':0.05,
    #'zoom_range':[1/1.2,1.2],
    'fill_mode':'nearest',
    'cval':0,
    'horizontal_flip':True,
    #'vertical_flip':True,
}

# %%
#resize image to (299,299)
#filepath is the 'train' folder path of the download data
filepath='train'
batch_generator=batch_data_generator(image_size=(299,299),resize=True,num_threads=8)
#split 10% data as a validation set from the training set 
train_batch=batch_generator.get_batch(filepath,batch_size=32,preprocessing_setting=setting,
                                      batch_type='balance',split=0.1,tf_train='True')
validation_set=batch_generator.validation_set

# %%
#show classes
batch_generator.classes_dict
# Out:
# {'c0': 0,
#  'c1': 1,
#  'c2': 2,
#  'c3': 3,
#  'c4': 4,
#  'c5': 5,
#  'c6': 6,
#  'c7': 7,
#  'c8': 8,
#  'c9': 9}

# %%
#step of each epoch
batch_generator.epoch
# Out:
# 700

# %%
#set your training parameters 
train_op=service_operator(train_batch,system_setting=system_setting)
# Out:
# init test
# init End

# %%
#Start training
train_op.fit_generator(validation_set,steps_per_epoch=700,validation_steps=700,epochs=100,
                      learning_rate_decay_dict=False,learning_rate=0.0001,dropout_keep_prob=0.8,initial_epoch=0)
# Out:
# Current Step is 700 Current Epoch is 1
# Current Step is 1400 Current Epoch is 2
# Current Step is 2100 Current Epoch is 3
# Current Step is 2800 Current Epoch is 4
# Current Step is 3500 Current Epoch is 5
# Current Step is 4200 Current Epoch is 6
# Current Step is 4900 Current Epoch is 7
# Current Step is 5600 Current Epoch is 8
# Current Step is 6300 Current Epoch is 9
# Current Step is 7000 Current Epoch is 10
# Current Step is 7700 Current Epoch is 11
# Current Step is 8400 Current Epoch is 12
# Current Step is 9100 Current Epoch is 13
# Current Step is 9800 Current Epoch is 14
# Current Step is 10500 Current Epoch is 15
# Current Step is 11200 Current Epoch is 16
# Current Step is 11900 Current Epoch is 17
# Current Step is 12600 Current Epoch is 18
# Current Step is 13300 Current Epoch is 19
# Current Step is 14000 Current Epoch is 20
# Current Step is 14700 Current Epoch is 21
# Current Step is 15400 Current Epoch is 22
# Current Step is 16100 Current Epoch is 23
# Current Step is 16800 Current Epoch is 24
# Current Step is 17500 Current Epoch is 25
# Current Step is 18200 Current Epoch is 26
# Current Step is 18900 Current Epoch is 27
# Current Step is 19600 Current Epoch is 28
# Current Step is 20300 Current Epoch is 29
# Current Step is 21000 Current Epoch is 30
# Current Step is 21700 Current Epoch is 31
# Current Step is 22400 Current Epoch is 32
# Current Step is 23100 Current Epoch is 33
# Current Step is 23800 Current Epoch is 34
# Current Step is 24500 Current Epoch is 35
# Current Step is 25200 Current Epoch is 36
# Current Step is 25900 Current Epoch is 37
# Current Step is 26600 Current Epoch is 38
# Current Step is 27300 Current Epoch is 39
# Current Step is 28000 Current Epoch is 40
# Current Step is 28700 Current Epoch is 41
# Current Step is 29400 Current Epoch is 42
# Current Step is 30100 Current Epoch is 43
# Current Step is 30800 Current Epoch is 44
# Current Step is 31500 Current Epoch is 45
# Current Step is 32200 Current Epoch is 46
# Current Step is 32900 Current Epoch is 47
# Current Step is 33600 Current Epoch is 48
# Current Step is 34300 Current Epoch is 49
# Current Step is 35000 Current Epoch is 50
# Current Step is 35700 Current Epoch is 51
# Current Step is 36400 Current Epoch is 52
# Current Step is 37100 Current Epoch is 53
# Current Step is 37800 Current Epoch is 54
# Current Step is 38500 Current Epoch is 55
# Current Step is 39200 Current Epoch is 56
# Current Step is 39900 Current Epoch is 57
# Current Step is 40600 Current Epoch is 58
# Current Step is 41300 Current Epoch is 59
# Current Step is 42000 Current Epoch is 60
# Current Step is 42700 Current Epoch is 61
# Current Step is 43400 Current Epoch is 62
# Current Step is 44100 Current Epoch is 63
# Current Step is 44800 Current Epoch is 64
# Current Step is 45500 Current Epoch is 65
# Current Step is 46200 Current Epoch is 66
# Current Step is 46900 Current Epoch is 67
# Current Step is 47600 Current Epoch is 68
# Current Step is 48300 Current Epoch is 69
# Current Step is 49000 Current Epoch is 70
# Current Step is 49700 Current Epoch is 71
# Current Step is 50400 Current Epoch is 72
# Current Step is 51100 Current Epoch is 73
# Current Step is 51800 Current Epoch is 74
# Current Step is 52500 Current Epoch is 75
# Current Step is 53200 Current Epoch is 76
# Current Step is 53900 Current Epoch is 77
# Current Step is 54600 Current Epoch is 78
# Current Step is 55300 Current Epoch is 79
# Current Step is 56000 Current Epoch is 80
# Current Step is 56700 Current Epoch is 81
# Current Step is 57400 Current Epoch is 82
# Current Step is 58100 Current Epoch is 83
# Current Step is 58800 Current Epoch is 84
# Current Step is 59500 Current Epoch is 85
# Current Step is 60200 Current Epoch is 86
# Current Step is 60900 Current Epoch is 87
# Current Step is 61600 Current Epoch is 88
# Current Step is 62300 Current Epoch is 89
# Current Step is 63000 Current Epoch is 90
# Current Step is 63700 Current Epoch is 91
# Current Step is 64400 Current Epoch is 92
# Current Step is 65100 Current Epoch is 93
# Current Step is 65800 Current Epoch is 94
# Current Step is 66500 Current Epoch is 95
# Current Step is 67200 Current Epoch is 96
# Current Step is 67900 Current Epoch is 97
# Current Step is 68600 Current Epoch is 98
# Current Step is 69300 Current Epoch is 99
# Current Step is 70000 Current Epoch is 100

# %%
train_op.dropout_keep_prob=0.8

# %%
#define a jpeg reader
def tf_image_reader():
    image_path_tensor = tf.placeholder(tf.string,name='image_path_tensor')
    image_contents = tf.read_file(image_path_tensor)
    image = tf.image.decode_jpeg(image_contents, channels=3)
    image_tensor=tf.image.resize_images(image,(299,299),method=1)
    sess=tf.Session()
    return image_path_tensor,image_tensor,sess

image_path_tensor,image_tensor,sess = tf_image_reader()    

#Show all predictions of test files 
current_dir = system_setting['current_dir']
test_files_path = os.path.join(current_dir,'test_image')
test_files = os.listdir(test_files_path)
for filename in test_files:
    image_path = os.path.join(test_files_path,filename)
    image = sess.run(image_tensor,feed_dict={image_path_tensor:image_path})
    
    pred=train_op.predict([[image]])[0]
    pred_class=list(batch_generator.classes_dict.keys())[pred.argmax(1)[0]]
    print("Your Class is %s" %pred_class)
    
    plt.imshow(image)
    plt.show()
    
'''
c0: safe driving
c1: texting - right
c2: talking on the phone - right
c3: texting - left
c4: talking on the phone - left
c5: operating the radio
c6: drinking
c7: reaching behind
c8: hair and makeup
c9: talking to passenger
'''
# Out:
# Your Class is c4
# Your Class is c3
# Your Class is c6
# Your Class is c1
# Your Class is c7
# Your Class is c8
# '\nc0: safe driving\nc1: texting - right\nc2: talking on the phone - right\nc3: texting - left\nc4: talking on the phone - left\nc5: operating the radio\nc6: drinking\nc7: reaching behind\nc8: hair and makeup\nc9: talking to passenger\n'
